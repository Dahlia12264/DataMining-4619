# %%
import pandas as pd
df=pd.read_csv("buah.csv")
df.head(30)
# Out:
#     tahun jenis_tanaman  jumlah_pohon  produksi
# 0    2007       Alpukat           426       468
# 1    2007        Mangga         28567     18165
# 2    2007      Rambutan         16035     11444
# 3    2007  Duku/Langsat          4200       606
# 4    2007         Jeruk             0         0
# 5    2007        Durian          1800       666
# 6    2007    Jambu Biji         16601      8351
# 7    2007     Jambu Air         20852     10589
# 8    2007          Sawo          2605      1713
# 9    2007        Pepaya          9599      8482
# 10   2007        Pisang         33926     10407
# 11   2007         Salak          5825       860
# 12   2007     Belimbing         54125     32263
# 13   2007        Nangka          5706      7019
# 14   2007        Sirsak           325       141
# 15   2007         Sukun           895       413
# 16   2008       Alpukat           869       493
# 17   2008        Mangga         60604     26911
# 18   2008      Rambutan         25335      6946
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tahun          80 non-null     int64
#  1   jenis_tanaman  80 non-null     object
#  2   jumlah_pohon   80 non-null     int64
#  3   produksi       80 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.6+ KB

# %%
korelasi=df.corr()
korelasi
# Out:
#                  tahun  jumlah_pohon  produksi
# tahun         1.000000      0.041167  0.046456
# jumlah_pohon  0.041167      1.000000  0.926396
# produksi      0.046456      0.926396  1.000000

# %%
import seaborn as sns
sns.heatmap(korelasi);

# %%
sns.boxplot(x='tahun',data=df);

# %%
sns.boxplot(x='jumlah_pohon',data=df);

# %%
sns.boxplot(x='produksi',data=df);

# %%
df
# Out:
#     tahun jenis_tanaman  jumlah_pohon  produksi
# 0    2007       Alpukat           426       468
# 1    2007        Mangga         28567     18165
# 2    2007      Rambutan         16035     11444
# 3    2007  Duku/Langsat          4200       606
# 4    2007         Jeruk             0         0
# ..    ...           ...           ...       ...
# 75   2011         Salak          4239       312
# 76   2011     Belimbing         89173     56163
# 77   2011        Nangka         10201      5333
# 78   2011        Sirsak           214        20
# 79   2011         Sukun          1068       164
#
# [80 rows x 4 columns]

# %%
pd.isnull(df).sum()
# Out:
# tahun            0
# jenis_tanaman    0
# jumlah_pohon     0
# produksi         0
# dtype: int64

# %%
df.dropna()
# Out:
#     tahun jenis_tanaman  jumlah_pohon  produksi
# 0    2007       Alpukat           426       468
# 1    2007        Mangga         28567     18165
# 2    2007      Rambutan         16035     11444
# 3    2007  Duku/Langsat          4200       606
# 4    2007         Jeruk             0         0
# ..    ...           ...           ...       ...
# 75   2011         Salak          4239       312
# 76   2011     Belimbing         89173     56163
# 77   2011        Nangka         10201      5333
# 78   2011        Sirsak           214        20
# 79   2011         Sukun          1068       164
#
# [80 rows x 4 columns]
